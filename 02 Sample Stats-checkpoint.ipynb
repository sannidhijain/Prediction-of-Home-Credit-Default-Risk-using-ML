# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None
pd.options.display.max_rows=None

import scipy.stats as stats

# %%
df_pop = pd.read_csv(r'application_train.csv\application_train.csv')

# %%
df_samp = pd.read_csv('application_train_40k.csv')

# %%
df_samp = df_pop.sample(40000)

# %%
df_pop.shape
# Out:
# (307511, 121)

# %%
df_samp.shape
# Out:
# (40000, 121)

# %% [markdown]
# ### Remove extra column from sample

# %%
for col in df_samp.columns:
    if col not in df_pop.columns:
        print(col)

# %%
df_samp.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# ### Remove ID column

# %%
df_pop.drop('SK_ID_CURR',axis=1,inplace=True)
df_samp.drop('SK_ID_CURR',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-c59a0b532e37> in <module>
# ----> 1 df_pop.drop('SK_ID_CURR',axis=1,inplace=True)
#       2 df_samp.drop('SK_ID_CURR',axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['SK_ID_CURR'] not found in axis"

# %% [markdown]
# ### nuniques and dtypes of Sample and Population

# %%
nunique_pop = df_pop.apply(lambda col:col.nunique())
nunique_sam = df_samp.apply(lambda col:col.nunique())

dtype_pop = df_pop.dtypes
dtype_samp = df_samp.dtypes

dx = pd.DataFrame({'Population nuniques':nunique_pop,
                   'Sample nuniques':nunique_sam,
                    'Population Dtype':dtype_pop,
                  'Sample Dtype ':dtype_samp},
                 index = df_pop.columns)
dx
# Out:
#                               Population nuniques  Sample nuniques  \
# TARGET                                          2                2
# NAME_CONTRACT_TYPE                              2                2
# CODE_GENDER                                     3                2
# FLAG_OWN_CAR                                    2                2
# FLAG_OWN_REALTY                                 2                2
# CNT_CHILDREN                                   15                8
# AMT_INCOME_TOTAL                             2548              679
# AMT_CREDIT                                   5603             3161
# AMT_ANNUITY                                 13672             8121
# AMT_GOODS_PRICE                              1002              500
# NAME_TYPE_SUITE                                 7                7
# NAME_INCOME_TYPE                                8                6
# NAME_EDUCATION_TYPE                             5                5
# NAME_FAMILY_STATUS                              6                5
# NAME_HOUSING_TYPE                               6                6
# REGION_POPULATION_RELATIVE                     81               80
# DAYS_BIRTH                                  17460            14929
# DAYS_EMPLOYED                               12574             7482
# DAYS_REGISTRATION                           15688            12146
# DAYS_ID_PUBLISH                              6168             5684
# OWN_CAR_AGE                                    62               52
# FLAG_MOBIL                                      2                2
# FLAG_EMP_PHONE                                  2                2
# FLAG_WORK_PHONE                                 2                2
# FLAG_CONT_MOBILE                                2                2
# FLAG_PHONE                                      2                2
# FLAG_EMAIL                                      2                2
# OCCUPATION_TYPE                                18               18
# CNT_FAM_MEMBERS                                17                9
# REGION_RATING_CLIENT                            3                3
# REGION_RATING_CLIENT_W_CITY                     3                3
# WEEKDAY_APPR_PROCESS_START                      7                7
# HOUR_APPR_PROCESS_START                        24               24
# REG_REGION_NOT_LIVE_REGION                      2                2
# REG_REGION_NOT_WORK_REGION                      2                2
# LIVE_REGION_NOT_WORK_REGION                     2                2
# REG_CITY_NOT_LIVE_CITY                          2                2
# REG_CITY_NOT_WORK_CITY                          2                2
# LIVE_CITY_NOT_WORK_CITY                         2                2
# ORGANIZATION_TYPE                              58               57
# EXT_SOURCE_1                               114584            17035
# EXT_SOURCE_2                               119831            32692
# EXT_SOURCE_3                                  814              731
# APARTMENTS_AVG                               2339             1360
# BASEMENTAREA_AVG                             3780             2648
# YEARS_BEGINEXPLUATATION_AVG                   285              166
# YEARS_BUILD_AVG                               149              127
# COMMONAREA_AVG                               3181             1827
# ELEVATORS_AVG                                 257              161
# ENTRANCES_AVG                                 285              175
# FLOORSMAX_AVG                                 403              213
# FLOORSMIN_AVG                                 305              157
# LANDAREA_AVG                                 3527             2385
# LIVINGAPARTMENTS_AVG                         1868             1065
# LIVINGAREA_AVG                               5199             3510
# NONLIVINGAPARTMENTS_AVG                       386              204
# NONLIVINGAREA_AVG                            3290             1836
# APARTMENTS_MODE                               760              590
# BASEMENTAREA_MODE                            3841             2672
# YEARS_BEGINEXPLUATATION_MODE                  221              155
# YEARS_BUILD_MODE                              154              127
# COMMONAREA_MODE                              3128             1794
# ELEVATORS_MODE                                 26               26
# ENTRANCES_MODE                                 30               29
# FLOORSMAX_MODE                                 25               25
# FLOORSMIN_MODE                                 25               25
# LANDAREA_MODE                                3563             2383
# LIVINGAPARTMENTS_MODE                         736              563
# LIVINGAREA_MODE                              5301             3534
# NONLIVINGAPARTMENTS_MODE                      167               89
# NONLIVINGAREA_MODE                           3327             1838
# APARTMENTS_MEDI                              1148              852
# BASEMENTAREA_MEDI                            3772             2641
# YEARS_BEGINEXPLUATATION_MEDI                  245              155
# YEARS_BUILD_MEDI                              151              129
# COMMONAREA_MEDI                              3202             1833
# ELEVATORS_MEDI                                 46               43
# ENTRANCES_MEDI                                 46               43
# FLOORSMAX_MEDI                                 49               44
# FLOORSMIN_MEDI                                 47               42
# LANDAREA_MEDI                                3560             2403
# LIVINGAPARTMENTS_MEDI                        1097              770
# LIVINGAREA_MEDI                              5281             3561
# NONLIVINGAPARTMENTS_MEDI                      214              116
# NONLIVINGAREA_MEDI                           3323             1837
# FONDKAPREMONT_MODE                              4                4
# HOUSETYPE_MODE                                  3                3
# TOTALAREA_MODE                               5116             3501
# WALLSMATERIAL_MODE                              7                7
# EMERGENCYSTATE_MODE                             2                2
# OBS_30_CNT_SOCIAL_CIRCLE                       33               29
# DEF_30_CNT_SOCIAL_CIRCLE                       10                6
# OBS_60_CNT_SOCIAL_CIRCLE                       33               28
# DEF_60_CNT_SOCIAL_CIRCLE                        9                6
# DAYS_LAST_PHONE_CHANGE                       3773             3322
# FLAG_DOCUMENT_2                                 2                2
# FLAG_DOCUMENT_3                                 2                2
# FLAG_DOCUMENT_4                                 2                2
# FLAG_DOCUMENT_5                                 2                2
# FLAG_DOCUMENT_6                                 2                2
# FLAG_DOCUMENT_7                                 2                2
# FLAG_DOCUMENT_8                                 2                2
# FLAG_DOCUMENT_9                                 2                2
# FLAG_DOCUMENT_10                                2                2
# FLAG_DOCUMENT_11                                2                2
# FLAG_DOCUMENT_12                                2                1
# FLAG_DOCUMENT_13                                2                2
# FLAG_DOCUMENT_14                                2                2
# FLAG_DOCUMENT_15                                2                2
# FLAG_DOCUMENT_16                                2                2
# FLAG_DOCUMENT_17                                2                2
# FLAG_DOCUMENT_18                                2                2
# FLAG_DOCUMENT_19                                2                2
# FLAG_DOCUMENT_20                                2                2
# FLAG_DOCUMENT_21                                2                2
# AMT_REQ_CREDIT_BUREAU_HOUR                      5                4
# AMT_REQ_CREDIT_BUREAU_DAY                       9                6
# AMT_REQ_CREDIT_BUREAU_WEEK                      9                8
# AMT_REQ_CREDIT_BUREAU_MON                      24               19
# AMT_REQ_CREDIT_BUREAU_QRT                      11                9
# AMT_REQ_CREDIT_BUREAU_YEAR                     25               17
#
#                              Population Dtype Sample Dtype
# TARGET                                  int64         int64
# NAME_CONTRACT_TYPE                     object        object
# CODE_GENDER                            object        object
# FLAG_OWN_CAR                           object        object
# FLAG_OWN_REALTY                        object        object
# CNT_CHILDREN                            int64         int64
# AMT_INCOME_TOTAL                      float64       float64
# AMT_CREDIT                            float64       float64
# AMT_ANNUITY                           float64       float64
# AMT_GOODS_PRICE                       float64       float64
# NAME_TYPE_SUITE                        object        object
# NAME_INCOME_TYPE                       object        object
# NAME_EDUCATION_TYPE                    object        object
# NAME_FAMILY_STATUS                     object        object
# NAME_HOUSING_TYPE                      object        object
# REGION_POPULATION_RELATIVE            float64       float64
# DAYS_BIRTH                              int64         int64
# DAYS_EMPLOYED                           int64         int64
# DAYS_REGISTRATION                     float64       float64
# DAYS_ID_PUBLISH                         int64         int64
# OWN_CAR_AGE                           float64       float64
# FLAG_MOBIL                              int64         int64
# FLAG_EMP_PHONE                          int64         int64
# FLAG_WORK_PHONE                         int64         int64
# FLAG_CONT_MOBILE                        int64         int64
# FLAG_PHONE                              int64         int64
# FLAG_EMAIL                              int64         int64
# OCCUPATION_TYPE                        object        object
# CNT_FAM_MEMBERS                       float64       float64
# REGION_RATING_CLIENT                    int64         int64
# REGION_RATING_CLIENT_W_CITY             int64         int64
# WEEKDAY_APPR_PROCESS_START             object        object
# HOUR_APPR_PROCESS_START                 int64         int64
# REG_REGION_NOT_LIVE_REGION              int64         int64
# REG_REGION_NOT_WORK_REGION              int64         int64
# LIVE_REGION_NOT_WORK_REGION             int64         int64
# REG_CITY_NOT_LIVE_CITY                  int64         int64
# REG_CITY_NOT_WORK_CITY                  int64         int64
# LIVE_CITY_NOT_WORK_CITY                 int64         int64
# ORGANIZATION_TYPE                      object        object
# EXT_SOURCE_1                          float64       float64
# EXT_SOURCE_2                          float64       float64
# EXT_SOURCE_3                          float64       float64
# APARTMENTS_AVG                        float64       float64
# BASEMENTAREA_AVG                      float64       float64
# YEARS_BEGINEXPLUATATION_AVG           float64       float64
# YEARS_BUILD_AVG                       float64       float64
# COMMONAREA_AVG                        float64       float64
# ELEVATORS_AVG                         float64       float64
# ENTRANCES_AVG                         float64       float64
# FLOORSMAX_AVG                         float64       float64
# FLOORSMIN_AVG                         float64       float64
# LANDAREA_AVG                          float64       float64
# LIVINGAPARTMENTS_AVG                  float64       float64
# LIVINGAREA_AVG                        float64       float64
# NONLIVINGAPARTMENTS_AVG               float64       float64
# NONLIVINGAREA_AVG                     float64       float64
# APARTMENTS_MODE                       float64       float64
# BASEMENTAREA_MODE                     float64       float64
# YEARS_BEGINEXPLUATATION_MODE          float64       float64
# YEARS_BUILD_MODE                      float64       float64
# COMMONAREA_MODE                       float64       float64
# ELEVATORS_MODE                        float64       float64
# ENTRANCES_MODE                        float64       float64
# FLOORSMAX_MODE                        float64       float64
# FLOORSMIN_MODE                        float64       float64
# LANDAREA_MODE                         float64       float64
# LIVINGAPARTMENTS_MODE                 float64       float64
# LIVINGAREA_MODE                       float64       float64
# NONLIVINGAPARTMENTS_MODE              float64       float64
# NONLIVINGAREA_MODE                    float64       float64
# APARTMENTS_MEDI                       float64       float64
# BASEMENTAREA_MEDI                     float64       float64
# YEARS_BEGINEXPLUATATION_MEDI          float64       float64
# YEARS_BUILD_MEDI                      float64       float64
# COMMONAREA_MEDI                       float64       float64
# ELEVATORS_MEDI                        float64       float64
# ENTRANCES_MEDI                        float64       float64
# FLOORSMAX_MEDI                        float64       float64
# FLOORSMIN_MEDI                        float64       float64
# LANDAREA_MEDI                         float64       float64
# LIVINGAPARTMENTS_MEDI                 float64       float64
# LIVINGAREA_MEDI                       float64       float64
# NONLIVINGAPARTMENTS_MEDI              float64       float64
# NONLIVINGAREA_MEDI                    float64       float64
# FONDKAPREMONT_MODE                     object        object
# HOUSETYPE_MODE                         object        object
# TOTALAREA_MODE                        float64       float64
# WALLSMATERIAL_MODE                     object        object
# EMERGENCYSTATE_MODE                    object        object
# OBS_30_CNT_SOCIAL_CIRCLE              float64       float64
# DEF_30_CNT_SOCIAL_CIRCLE              float64       float64
# OBS_60_CNT_SOCIAL_CIRCLE              float64       float64
# DEF_60_CNT_SOCIAL_CIRCLE              float64       float64
# DAYS_LAST_PHONE_CHANGE                float64       float64
# FLAG_DOCUMENT_2                         int64         int64
# FLAG_DOCUMENT_3                         int64         int64
# FLAG_DOCUMENT_4                         int64         int64
# FLAG_DOCUMENT_5                         int64         int64
# FLAG_DOCUMENT_6                         int64         int64
# FLAG_DOCUMENT_7                         int64         int64
# FLAG_DOCUMENT_8                         int64         int64
# FLAG_DOCUMENT_9                         int64         int64
# FLAG_DOCUMENT_10                        int64         int64
# FLAG_DOCUMENT_11                        int64         int64
# FLAG_DOCUMENT_12                        int64         int64
# FLAG_DOCUMENT_13                        int64         int64
# FLAG_DOCUMENT_14                        int64         int64
# FLAG_DOCUMENT_15                        int64         int64
# FLAG_DOCUMENT_16                        int64         int64
# FLAG_DOCUMENT_17                        int64         int64
# FLAG_DOCUMENT_18                        int64         int64
# FLAG_DOCUMENT_19                        int64         int64
# FLAG_DOCUMENT_20                        int64         int64
# FLAG_DOCUMENT_21                        int64         int64
# AMT_REQ_CREDIT_BUREAU_HOUR            float64       float64
# AMT_REQ_CREDIT_BUREAU_DAY             float64       float64
# AMT_REQ_CREDIT_BUREAU_WEEK            float64       float64
# AMT_REQ_CREDIT_BUREAU_MON             float64       float64
# AMT_REQ_CREDIT_BUREAU_QRT             float64       float64
# AMT_REQ_CREDIT_BUREAU_YEAR            float64       float64

# %% [markdown]
# ## Statistical tests between Sample and Population

# %% [markdown]
# ### Numerical columns

# %%
def num_sample_pop_test(col,alpha = 0.05):
    pop = df_pop[col]
    samp = df_samp[col]
    
    pop_mean = pop.mean()
    samp_mean = samp.mean()
    
    pop_std = pop.std()
    samp_std = samp.std()
    
    x_bar = samp_mean
    n = len(samp)
    sigma = pop_std

    z_alpha_by_2 = stats.norm.isf(alpha/2)

    upper = x_bar + z_alpha_by_2 * sigma / n**0.5
    lower = x_bar - z_alpha_by_2 * sigma / n**0.5
    #print('95% Conf interval:', lower, upper)

    if lower<=samp_mean<=upper:
        print(f'{col} Sample reperesents Population')
        return (col,1)
    else:
        print(f'{col} Sample and Population are different')
        return (col,0)

# %%
num_cols = df_pop.select_dtypes(np.number)
l = []
for col in num_cols:
    l.append(num_sample_pop_test(col))
# Out:
# TARGET Sample reperesents Population
# CNT_CHILDREN Sample reperesents Population
# AMT_INCOME_TOTAL Sample reperesents Population
# AMT_CREDIT Sample reperesents Population
# AMT_ANNUITY Sample reperesents Population
# AMT_GOODS_PRICE Sample reperesents Population
# REGION_POPULATION_RELATIVE Sample reperesents Population
# DAYS_BIRTH Sample reperesents Population
# DAYS_EMPLOYED Sample reperesents Population
# DAYS_REGISTRATION Sample reperesents Population
# DAYS_ID_PUBLISH Sample reperesents Population
# OWN_CAR_AGE Sample reperesents Population
# FLAG_MOBIL Sample reperesents Population
# FLAG_EMP_PHONE Sample reperesents Population
# FLAG_WORK_PHONE Sample reperesents Population
# FLAG_CONT_MOBILE Sample reperesents Population
# FLAG_PHONE Sample reperesents Population
# FLAG_EMAIL Sample reperesents Population
# CNT_FAM_MEMBERS Sample reperesents Population
# REGION_RATING_CLIENT Sample reperesents Population
# REGION_RATING_CLIENT_W_CITY Sample reperesents Population
# HOUR_APPR_PROCESS_START Sample reperesents Population
# REG_REGION_NOT_LIVE_REGION Sample reperesents Population
# REG_REGION_NOT_WORK_REGION Sample reperesents Population
# LIVE_REGION_NOT_WORK_REGION Sample reperesents Population
# REG_CITY_NOT_LIVE_CITY Sample reperesents Population
# REG_CITY_NOT_WORK_CITY Sample reperesents Population
# LIVE_CITY_NOT_WORK_CITY Sample reperesents Population
# EXT_SOURCE_1 Sample reperesents Population
# EXT_SOURCE_2 Sample reperesents Population
# EXT_SOURCE_3 Sample reperesents Population
# APARTMENTS_AVG Sample reperesents Population
# BASEMENTAREA_AVG Sample reperesents Population
# YEARS_BEGINEXPLUATATION_AVG Sample reperesents Population
# YEARS_BUILD_AVG Sample reperesents Population
# COMMONAREA_AVG Sample reperesents Population
# ELEVATORS_AVG Sample reperesents Population
# ENTRANCES_AVG Sample reperesents Population
# FLOORSMAX_AVG Sample reperesents Population
# FLOORSMIN_AVG Sample reperesents Population
# LANDAREA_AVG Sample reperesents Population
# LIVINGAPARTMENTS_AVG Sample reperesents Population
# LIVINGAREA_AVG Sample reperesents Population
# NONLIVINGAPARTMENTS_AVG Sample reperesents Population
# NONLIVINGAREA_AVG Sample reperesents Population
# APARTMENTS_MODE Sample reperesents Population
# BASEMENTAREA_MODE Sample reperesents Population
# YEARS_BEGINEXPLUATATION_MODE Sample reperesents Population
# YEARS_BUILD_MODE Sample reperesents Population
# COMMONAREA_MODE Sample reperesents Population
# ELEVATORS_MODE Sample reperesents Population
# ENTRANCES_MODE Sample reperesents Population
# FLOORSMAX_MODE Sample reperesents Population
# FLOORSMIN_MODE Sample reperesents Population
# LANDAREA_MODE Sample reperesents Population
# LIVINGAPARTMENTS_MODE Sample reperesents Population
# LIVINGAREA_MODE Sample reperesents Population
# NONLIVINGAPARTMENTS_MODE Sample reperesents Population
# NONLIVINGAREA_MODE Sample reperesents Population
# APARTMENTS_MEDI Sample reperesents Population
# BASEMENTAREA_MEDI Sample reperesents Population
# YEARS_BEGINEXPLUATATION_MEDI Sample reperesents Population
# YEARS_BUILD_MEDI Sample reperesents Population
# COMMONAREA_MEDI Sample reperesents Population
# ELEVATORS_MEDI Sample reperesents Population
# ENTRANCES_MEDI Sample reperesents Population
# FLOORSMAX_MEDI Sample reperesents Population
# FLOORSMIN_MEDI Sample reperesents Population
# LANDAREA_MEDI Sample reperesents Population
# LIVINGAPARTMENTS_MEDI Sample reperesents Population
# LIVINGAREA_MEDI Sample reperesents Population
# NONLIVINGAPARTMENTS_MEDI Sample reperesents Population
# NONLIVINGAREA_MEDI Sample reperesents Population
# TOTALAREA_MODE Sample reperesents Population
# OBS_30_CNT_SOCIAL_CIRCLE Sample reperesents Population
# DEF_30_CNT_SOCIAL_CIRCLE Sample reperesents Population
# OBS_60_CNT_SOCIAL_CIRCLE Sample reperesents Population
# DEF_60_CNT_SOCIAL_CIRCLE Sample reperesents Population
# DAYS_LAST_PHONE_CHANGE Sample reperesents Population
# FLAG_DOCUMENT_2 Sample reperesents Population
# FLAG_DOCUMENT_3 Sample reperesents Population
# FLAG_DOCUMENT_4 Sample reperesents Population
# FLAG_DOCUMENT_5 Sample reperesents Population
# FLAG_DOCUMENT_6 Sample reperesents Population
# FLAG_DOCUMENT_7 Sample reperesents Population
# FLAG_DOCUMENT_8 Sample reperesents Population
# FLAG_DOCUMENT_9 Sample reperesents Population
# FLAG_DOCUMENT_10 Sample reperesents Population
# FLAG_DOCUMENT_11 Sample reperesents Population
# FLAG_DOCUMENT_12 Sample reperesents Population
# FLAG_DOCUMENT_13 Sample reperesents Population
# FLAG_DOCUMENT_14 Sample reperesents Population
# FLAG_DOCUMENT_15 Sample reperesents Population
# FLAG_DOCUMENT_16 Sample reperesents Population
# FLAG_DOCUMENT_17 Sample reperesents Population
# FLAG_DOCUMENT_18 Sample reperesents Population
# FLAG_DOCUMENT_19 Sample reperesents Population
# FLAG_DOCUMENT_20 Sample reperesents Population
# FLAG_DOCUMENT_21 Sample reperesents Population
# AMT_REQ_CREDIT_BUREAU_HOUR Sample reperesents Population
# AMT_REQ_CREDIT_BUREAU_DAY Sample reperesents Population
# AMT_REQ_CREDIT_BUREAU_WEEK Sample reperesents Population
# AMT_REQ_CREDIT_BUREAU_MON Sample reperesents Population
# AMT_REQ_CREDIT_BUREAU_QRT Sample reperesents Population
# AMT_REQ_CREDIT_BUREAU_YEAR Sample reperesents Population

# %%
[i for i in l if i[1]==0] #all numerical samples are statiscally representing population
# Out:
# []

# %% [markdown]
# ### Categorical Columns

# %%
def cat_samp_pop_test(col,alpha=0.05):
    observed = df_samp[col].value_counts()
    expected = df_pop[col].value_counts(normalize=True)*np.sum(observed)
    
    cats_not_in_samp = []
    for cat in expected.index:
        if cat not in observed.index:
            cats_not_in_samp.append(cat)
    observed = observed.append(pd.Series([0]*len(cats_not_in_samp),index=cats_not_in_samp,dtype=np.number))
    
    display(pd.DataFrame([observed,expected],index=['observed','expected']))
    
    chi2_stat,p_val = stats.chisquare(f_obs = observed, f_exp = expected)
    
    if p_val > alpha/2:
        print(f'{col} Sample represents the Population')
        return (col,1)
    else:
        print(f'{col} Sample and Population are different')
        return (col,0)

# %%
cat_cols = df_pop.select_dtypes(object)
l = []
for col in cat_cols:
    l.append(cat_samp_pop_test(col,alpha=0.1))
# Out:
#             Cash loans  Revolving loans
# observed  36245.000000      3755.000000
# expected  36191.485833      3808.514167
# NAME_CONTRACT_TYPE Sample represents the Population
#                      F             M       XNA
# observed  26384.000000  13616.000000  0.000000
# expected  26333.757166  13665.722527  0.520307
# CODE_GENDER Sample represents the Population
#                      N             Y
# observed  26444.000000  13556.000000
# expected  26395.673651  13604.326349
# FLAG_OWN_CAR Sample represents the Population
#                      Y             N
# observed  27709.000000  12291.000000
# expected  27746.909867  12253.090133
# FLAG_OWN_REALTY Sample represents the Population
#           Unaccompanied       Family  Spouse, partner    Children     Other_B  \
# observed   32202.000000  5300.000000      1497.000000  435.000000  231.000000
# expected   32313.679719  5220.226162      1478.342461  424.779667  230.137745
#
#              Other_A  Group of people
# observed  110.000000        40.000000
# expected  112.598467        35.235779
# NAME_TYPE_SUITE Sample represents the Population
#                Working  Commercial associate    Pensioner  State servant  \
# observed  20704.000000           9219.000000  7308.000000    2767.000000
# expected  20652.789656           9315.699276  7201.303368    2823.053484
#
#           Unemployed  Student  Businessman  Maternity leave
# observed    1.000000  1.00000     0.000000         0.000000
# expected    2.861686  2.34138     1.300766         0.650383
# NAME_INCOME_TYPE Sample represents the Population
#           Secondary / secondary special  Higher education  Incomplete higher  \
# observed                    28436.00000       9703.000000        1344.000000
# expected                    28407.56916       9737.928074        1336.797708
#
#           Lower secondary  Academic degree
# observed       494.000000         23.00000
# expected       496.372487         21.33257
# NAME_EDUCATION_TYPE Sample represents the Population
#                Married  Single / not married  Civil marriage    Separated  \
# observed  25549.000000           5949.000000     3810.000000  2571.000000
# expected  25551.216054           5911.203176     3873.032184  2571.615324
#
#                 Widow   Unknown
# observed  2121.000000  0.000000
# expected  2092.673108  0.260153
# NAME_FAMILY_STATUS Sample represents the Population
#           House / apartment  With parents  Municipal apartment  \
# observed       35478.000000   1885.000000          1473.000000
# expected       35493.754695   1930.337451          1454.647151
#
#           Rented apartment  Office apartment  Co-op apartment
# observed        652.000000        362.000000       150.000000
# expected        634.904117        340.410587       145.945999
# NAME_HOUSING_TYPE Sample represents the Population
#              Laborers  Sales staff   Core staff     Managers      Drivers  \
# observed  7099.000000    4241.0000  3522.000000  2783.000000  2387.000000
# expected  7134.290915    4150.0563  3564.172082  2762.782792  2404.943534
#
#           High skill tech staff  Accountants  Medicine staff  Security staff  \
# observed            1480.000000  1215.000000     1064.000000      885.000000
# expected            1471.174403  1268.597049     1103.639357      868.871983
#
#           Cooking staff  Cleaning staff  Private service staff  \
# observed     747.000000      649.000000             337.000000
# expected     768.682162      601.526757             342.843103
#
#           Low-skill Laborers  Waiters/barmen staff  Secretaries  \
# observed          276.000000             193.00000   167.000000
# expected          270.577155             174.26565   168.706731
#
#           Realty agents   HR staff   IT staff
# observed     104.000000  74.000000  70.000000
# expected      97.087168  72.783057  67.999801
# OCCUPATION_TYPE Sample represents the Population
#               TUESDAY   WEDNESDAY      MONDAY     THURSDAY      FRIDAY  \
# observed  7136.000000  6731.00000  6567.00000  6520.000000  6515.00000
# expected  7011.261386  6755.40062  6596.70711  6580.707682  6547.79829
#
#              SATURDAY       SUNDAY
# observed  4444.000000  2087.000000
# expected  4403.354677  2104.770236
# WEEKDAY_APPR_PROCESS_START Sample represents the Population
#           Business Entity Type 3          XNA  Self-employed        Other  \
# observed             8857.000000  7308.000000     5041.00000  2175.000000
# expected             8844.171428  7202.864288     4996.50419  2170.068713
#
#              Medicine   Government  Business Entity Type 2       School  \
# observed  1404.000000  1363.000000             1340.000000  1201.000000
# expected  1455.947917  1353.317442             1372.698863  1156.771628
#
#           Trade: type 7  Kindergarten  Construction  Business Entity Type 1  \
# observed    1065.000000    851.000000    849.000000               779.00000
# expected    1018.630228    894.927336    874.245149               778.37866
#
#           Transport: type 4  Trade: type 3  Industry: type 9    Security  \
# observed         760.000000     465.000000        434.000000  414.000000
# expected         702.153744     454.227654        438.098149  422.358875
#
#           Industry: type 3  Industry: type 11     Housing   Military  \
# observed        403.000000         368.000000  349.000000  348.00000
# expected        426.391251         351.727255  384.766724  342.62189
#
#                 Bank  Agriculture      Police      Postal  \
# observed  315.000000   313.000000  299.000000  288.000000
# expected  326.102156   319.208093  304.509432  280.575329
#
#           Security Ministries  Transport: type 2  Trade: type 2  Restaurant  \
# observed           272.000000         245.000000     224.000000  223.000000
# expected           256.771302         286.688931     247.145631  235.568809
#
#            Services  University  Industry: type 7  Transport: type 3  \
# observed  167.00000  160.000000        160.000000         138.000000
# expected  204.87072  172.611711        170.010178         154.400981
#
#           Industry: type 1  Industry: type 4  Electricity       Hotel  \
# observed        130.000000         127.00000   122.000000  119.000000
# expected        135.149637         114.07722   123.572815  125.654042
#
#           Trade: type 6    Telecom  Industry: type 5  Insurance    Culture  \
# observed      89.000000  86.000000         80.000000  78.000000  59.000000
# expected      82.078365  75.054226         77.915912  77.655759  49.299049
#
#           Emergency  Advertising  Industry: type 2  Trade: type 1  \
# observed  56.000000    55.000000         52.000000      51.000000
# expected  72.842923    55.802882         59.575105      45.266673
#
#           Legal Services  Industry: type 12    Realtor     Mobile   Cleaning  \
# observed       48.000000          47.000000  46.000000  39.000000  38.000000
# expected       39.673378          47.998283  51.510352  41.234297  33.819928
#
#           Transport: type 1  Industry: type 6  Industry: type 10   Religion  \
# observed          27.000000         19.000000          17.000000  16.000000
# expected          26.145406         14.568585          14.178355  11.056515
#
#           Trade: type 5  Trade: type 4  Industry: type 13  Industry: type 8
# observed       8.000000       7.000000           6.000000           0.00000
# expected       6.373756       8.324905           8.715135           3.12184
# ORGANIZATION_TYPE Sample represents the Population
#           reg oper account  reg oper spec account  org spec account  \
# observed       9642.000000            1514.000000        754.000000
# expected       9614.546988            1573.123766        731.736957
#
#           not specified
# observed     750.000000
# expected     740.592289
# FONDKAPREMONT_MODE Sample represents the Population
#           block of flats  specific housing  terraced house
# observed    19592.000000         170.00000      161.000000
# expected    19570.478344         194.92068      157.600976
# HOUSETYPE_MODE Sample represents the Population
#                 Panel  Stone, brick        Block      Wooden       Mixed  \
# observed  8564.000000   8481.000000  1201.000000  675.000000  276.000000
# expected  8578.603427   8419.475789  1201.965741  696.524403  298.250658
#
#           Monolithic      Others
# observed    235.0000  205.000000
# expected    231.0923  211.087683
# WALLSMATERIAL_MODE Sample represents the Population
#                     No         Yes
# observed  20745.000000  307.000000
# expected  20749.018621  302.981379
# EMERGENCYSTATE_MODE Sample represents the Population

# %%
[i for i in l if i[1]==0] #all catogorical are good
# Out:
# []

# %% [markdown]
# ### Numerical with 0,1s which represents as Categorical

# %%
num_col = df_pop.select_dtypes(np.number).columns
d = dx.loc[num_col]
d = d[d['Population nuniques']<5]
d
# Out:
#                              Population nuniques  Sample nuniques  \
# TARGET                                         2                2
# FLAG_MOBIL                                     2                2
# FLAG_EMP_PHONE                                 2                2
# FLAG_WORK_PHONE                                2                2
# FLAG_CONT_MOBILE                               2                2
# FLAG_PHONE                                     2                2
# FLAG_EMAIL                                     2                2
# REGION_RATING_CLIENT                           3                3
# REGION_RATING_CLIENT_W_CITY                    3                3
# REG_REGION_NOT_LIVE_REGION                     2                2
# REG_REGION_NOT_WORK_REGION                     2                2
# LIVE_REGION_NOT_WORK_REGION                    2                2
# REG_CITY_NOT_LIVE_CITY                         2                2
# REG_CITY_NOT_WORK_CITY                         2                2
# LIVE_CITY_NOT_WORK_CITY                        2                2
# FLAG_DOCUMENT_2                                2                2
# FLAG_DOCUMENT_3                                2                2
# FLAG_DOCUMENT_4                                2                2
# FLAG_DOCUMENT_5                                2                2
# FLAG_DOCUMENT_6                                2                2
# FLAG_DOCUMENT_7                                2                2
# FLAG_DOCUMENT_8                                2                2
# FLAG_DOCUMENT_9                                2                2
# FLAG_DOCUMENT_10                               2                2
# FLAG_DOCUMENT_11                               2                2
# FLAG_DOCUMENT_12                               2                1
# FLAG_DOCUMENT_13                               2                2
# FLAG_DOCUMENT_14                               2                2
# FLAG_DOCUMENT_15                               2                2
# FLAG_DOCUMENT_16                               2                2
# FLAG_DOCUMENT_17                               2                2
# FLAG_DOCUMENT_18                               2                2
# FLAG_DOCUMENT_19                               2                2
# FLAG_DOCUMENT_20                               2                2
# FLAG_DOCUMENT_21                               2                2
#
#                             Population Dtype Sample Dtype
# TARGET                                 int64         int64
# FLAG_MOBIL                             int64         int64
# FLAG_EMP_PHONE                         int64         int64
# FLAG_WORK_PHONE                        int64         int64
# FLAG_CONT_MOBILE                       int64         int64
# FLAG_PHONE                             int64         int64
# FLAG_EMAIL                             int64         int64
# REGION_RATING_CLIENT                   int64         int64
# REGION_RATING_CLIENT_W_CITY            int64         int64
# REG_REGION_NOT_LIVE_REGION             int64         int64
# REG_REGION_NOT_WORK_REGION             int64         int64
# LIVE_REGION_NOT_WORK_REGION            int64         int64
# REG_CITY_NOT_LIVE_CITY                 int64         int64
# REG_CITY_NOT_WORK_CITY                 int64         int64
# LIVE_CITY_NOT_WORK_CITY                int64         int64
# FLAG_DOCUMENT_2                        int64         int64
# FLAG_DOCUMENT_3                        int64         int64
# FLAG_DOCUMENT_4                        int64         int64
# FLAG_DOCUMENT_5                        int64         int64
# FLAG_DOCUMENT_6                        int64         int64
# FLAG_DOCUMENT_7                        int64         int64
# FLAG_DOCUMENT_8                        int64         int64
# FLAG_DOCUMENT_9                        int64         int64
# FLAG_DOCUMENT_10                       int64         int64
# FLAG_DOCUMENT_11                       int64         int64
# FLAG_DOCUMENT_12                       int64         int64
# FLAG_DOCUMENT_13                       int64         int64
# FLAG_DOCUMENT_14                       int64         int64
# FLAG_DOCUMENT_15                       int64         int64
# FLAG_DOCUMENT_16                       int64         int64
# FLAG_DOCUMENT_17                       int64         int64
# FLAG_DOCUMENT_18                       int64         int64
# FLAG_DOCUMENT_19                       int64         int64
# FLAG_DOCUMENT_20                       int64         int64
# FLAG_DOCUMENT_21                       int64         int64

# %%
num_cat_cols = d.index
#categorical test
l = []
for col in num_cat_cols:
    l.append(cat_samp_pop_test(col))
# Out:
#                      0            1
# observed  36696.000000  3304.000000
# expected  36770.847222  3229.152778
# TARGET Sample represents the Population
#                      1         0
# observed  39999.000000  1.000000
# expected  39999.869923  0.130077
# FLAG_MOBIL Sample and Population are different
#                      1            0
# observed  32692.000000  7308.000000
# expected  32795.574792  7204.425208
# FLAG_EMP_PHONE Sample represents the Population
#                      0            1
# observed  32025.000000  7975.000000
# expected  32025.260885  7974.739115
# FLAG_WORK_PHONE Sample represents the Population
#                      1          0
# observed  39926.000000  74.000000
# expected  39925.336004  74.663996
# FLAG_CONT_MOBILE Sample represents the Population
#                      0             1
# observed  28646.000000  11354.000000
# expected  28757.345266  11242.654734
# FLAG_PHONE Sample represents the Population
#                      0            1
# observed  37740.000000  2260.000000
# expected  37731.203111  2268.796889
# FLAG_EMAIL Sample represents the Population
#                      2            3            1
# observed  29523.000000  6240.000000  4237.000000
# expected  29525.317794  6286.604382  4188.077825
# REGION_RATING_CLIENT Sample represents the Population
#                      2            3            1
# observed  29820.000000  5690.000000  4490.000000
# expected  29850.509413  5705.161767  4444.328821
# REGION_RATING_CLIENT_W_CITY Sample represents the Population
#                      0           1
# observed  39403.000000  597.000000
# expected  39394.233052  605.766948
# REG_REGION_NOT_LIVE_REGION Sample represents the Population
#                      0            1
# observed  38009.000000  1991.000000
# expected  37969.243377  2030.756623
# REG_REGION_NOT_WORK_REGION Sample represents the Population
#                      0            1
# observed  38384.000000  1616.000000
# expected  38373.651674  1626.348326
# LIVE_REGION_NOT_WORK_REGION Sample represents the Population
#                      0            1
# observed  36828.000000  3172.000000
# expected  36873.087467  3126.912533
# REG_CITY_NOT_LIVE_CITY Sample represents the Population
#                     0           1
# observed  30768.00000  9232.00000
# expected  30781.85821  9218.14179
# REG_CITY_NOT_WORK_CITY Sample represents the Population
#                      0            1
# observed  32794.000000  7206.000000
# expected  32817.817899  7182.182101
# LIVE_CITY_NOT_WORK_CITY Sample represents the Population
#                      0         1
# observed  39998.000000  2.000000
# expected  39998.309004  1.690996
# FLAG_DOCUMENT_2 Sample represents the Population
#                      1             0
# observed  28529.000000  11471.000000
# expected  28400.935251  11599.064749
# FLAG_DOCUMENT_3 Sample represents the Population
#                      0         1
# observed  39998.000000  2.000000
# expected  39996.748084  3.251916
# FLAG_DOCUMENT_4 Sample represents the Population
#                      0           1
# observed  39408.000000  592.000000
# expected  39395.403742  604.596258
# FLAG_DOCUMENT_5 Sample represents the Population
#                      0            1
# observed  36480.000000  3520.000000
# expected  36477.784535  3522.215465
# FLAG_DOCUMENT_6 Sample represents the Population
#                      0          1
# observed  39990.000000  10.000000
# expected  39992.325478   7.674522
# FLAG_DOCUMENT_7 Sample represents the Population
#                      0            1
# observed  36769.000000  3231.000000
# expected  36744.961969  3255.038031
# FLAG_DOCUMENT_8 Sample represents the Population
#                      0           1
# observed  39853.000000  147.000000
# expected  39844.168176  155.831824
# FLAG_DOCUMENT_9 Sample represents the Population
#                      0         1
# observed  39997.000000  3.000000
# expected  39999.089463  0.910537
# FLAG_DOCUMENT_10 Sample represents the Population
#                      0           1
# observed  39835.000000  165.000000
# expected  39843.517793  156.482207
# FLAG_DOCUMENT_11 Sample represents the Population
#                      0         1
# observed  40000.000000  0.000000
# expected  39999.739847  0.260153
# FLAG_DOCUMENT_12 Sample represents the Population
#                      0           1
# observed  39855.000000  145.000000
# expected  39858.996914  141.003086
# FLAG_DOCUMENT_13 Sample represents the Population
#                      0           1
# observed  39889.000000  111.000000
# expected  39882.540787  117.459213
# FLAG_DOCUMENT_14 Sample represents the Population
#                      0          1
# observed  39945.000000  55.000000
# expected  39951.611487  48.388513
# FLAG_DOCUMENT_15 Sample represents the Population
#                      0           1
# observed  39593.000000  407.000000
# expected  39602.875995  397.124005
# FLAG_DOCUMENT_16 Sample represents the Population
#                      0          1
# observed  39987.000000  13.000000
# expected  39989.333715  10.666285
# FLAG_DOCUMENT_17 Sample represents the Population
#                      0           1
# observed  39674.000000  326.000000
# expected  39674.808381  325.191619
# FLAG_DOCUMENT_18 Sample represents the Population
#                      0          1
# observed  39984.000000  16.000000
# expected  39976.195973  23.804027
# FLAG_DOCUMENT_19 Sample represents the Population
#                      0          1
# observed  39979.000000  21.000000
# expected  39979.708043  20.291957
# FLAG_DOCUMENT_20 Sample represents the Population
#                      0          1
# observed  39990.000000  10.000000
# expected  39986.602105  13.397895
# FLAG_DOCUMENT_21 Sample represents the Population

# %%
#alpha = 0.05
[i for i in l if i[1]==0] #not good fit samples are:
# Out:
# [('FLAG_MOBIL', 0)]

# %%
l = []
for col in num_cat_cols:
    l.append(cat_samp_pop_test(col,alpha=0.1))
# Out:
#                      0            1
# observed  36696.000000  3304.000000
# expected  36770.847222  3229.152778
# TARGET Sample represents the Population
#                      1         0
# observed  39999.000000  1.000000
# expected  39999.869923  0.130077
# FLAG_MOBIL Sample and Population are different
#                      1            0
# observed  32692.000000  7308.000000
# expected  32795.574792  7204.425208
# FLAG_EMP_PHONE Sample represents the Population
#                      0            1
# observed  32025.000000  7975.000000
# expected  32025.260885  7974.739115
# FLAG_WORK_PHONE Sample represents the Population
#                      1          0
# observed  39926.000000  74.000000
# expected  39925.336004  74.663996
# FLAG_CONT_MOBILE Sample represents the Population
#                      0             1
# observed  28646.000000  11354.000000
# expected  28757.345266  11242.654734
# FLAG_PHONE Sample represents the Population
#                      0            1
# observed  37740.000000  2260.000000
# expected  37731.203111  2268.796889
# FLAG_EMAIL Sample represents the Population
#                      2            3            1
# observed  29523.000000  6240.000000  4237.000000
# expected  29525.317794  6286.604382  4188.077825
# REGION_RATING_CLIENT Sample represents the Population
#                      2            3            1
# observed  29820.000000  5690.000000  4490.000000
# expected  29850.509413  5705.161767  4444.328821
# REGION_RATING_CLIENT_W_CITY Sample represents the Population
#                      0           1
# observed  39403.000000  597.000000
# expected  39394.233052  605.766948
# REG_REGION_NOT_LIVE_REGION Sample represents the Population
#                      0            1
# observed  38009.000000  1991.000000
# expected  37969.243377  2030.756623
# REG_REGION_NOT_WORK_REGION Sample represents the Population
#                      0            1
# observed  38384.000000  1616.000000
# expected  38373.651674  1626.348326
# LIVE_REGION_NOT_WORK_REGION Sample represents the Population
#                      0            1
# observed  36828.000000  3172.000000
# expected  36873.087467  3126.912533
# REG_CITY_NOT_LIVE_CITY Sample represents the Population
#                     0           1
# observed  30768.00000  9232.00000
# expected  30781.85821  9218.14179
# REG_CITY_NOT_WORK_CITY Sample represents the Population
#                      0            1
# observed  32794.000000  7206.000000
# expected  32817.817899  7182.182101
# LIVE_CITY_NOT_WORK_CITY Sample represents the Population
#                      0         1
# observed  39998.000000  2.000000
# expected  39998.309004  1.690996
# FLAG_DOCUMENT_2 Sample represents the Population
#                      1             0
# observed  28529.000000  11471.000000
# expected  28400.935251  11599.064749
# FLAG_DOCUMENT_3 Sample represents the Population
#                      0         1
# observed  39998.000000  2.000000
# expected  39996.748084  3.251916
# FLAG_DOCUMENT_4 Sample represents the Population
#                      0           1
# observed  39408.000000  592.000000
# expected  39395.403742  604.596258
# FLAG_DOCUMENT_5 Sample represents the Population
#                      0            1
# observed  36480.000000  3520.000000
# expected  36477.784535  3522.215465
# FLAG_DOCUMENT_6 Sample represents the Population
#                      0          1
# observed  39990.000000  10.000000
# expected  39992.325478   7.674522
# FLAG_DOCUMENT_7 Sample represents the Population
#                      0            1
# observed  36769.000000  3231.000000
# expected  36744.961969  3255.038031
# FLAG_DOCUMENT_8 Sample represents the Population
#                      0           1
# observed  39853.000000  147.000000
# expected  39844.168176  155.831824
# FLAG_DOCUMENT_9 Sample represents the Population
#                      0         1
# observed  39997.000000  3.000000
# expected  39999.089463  0.910537
# FLAG_DOCUMENT_10 Sample and Population are different
#                      0           1
# observed  39835.000000  165.000000
# expected  39843.517793  156.482207
# FLAG_DOCUMENT_11 Sample represents the Population
#                      0         1
# observed  40000.000000  0.000000
# expected  39999.739847  0.260153
# FLAG_DOCUMENT_12 Sample represents the Population
#                      0           1
# observed  39855.000000  145.000000
# expected  39858.996914  141.003086
# FLAG_DOCUMENT_13 Sample represents the Population
#                      0           1
# observed  39889.000000  111.000000
# expected  39882.540787  117.459213
# FLAG_DOCUMENT_14 Sample represents the Population
#                      0          1
# observed  39945.000000  55.000000
# expected  39951.611487  48.388513
# FLAG_DOCUMENT_15 Sample represents the Population
#                      0           1
# observed  39593.000000  407.000000
# expected  39602.875995  397.124005
# FLAG_DOCUMENT_16 Sample represents the Population
#                      0          1
# observed  39987.000000  13.000000
# expected  39989.333715  10.666285
# FLAG_DOCUMENT_17 Sample represents the Population
#                      0           1
# observed  39674.000000  326.000000
# expected  39674.808381  325.191619
# FLAG_DOCUMENT_18 Sample represents the Population
#                      0          1
# observed  39984.000000  16.000000
# expected  39976.195973  23.804027
# FLAG_DOCUMENT_19 Sample represents the Population
#                      0          1
# observed  39979.000000  21.000000
# expected  39979.708043  20.291957
# FLAG_DOCUMENT_20 Sample represents the Population
#                      0          1
# observed  39990.000000  10.000000
# expected  39986.602105  13.397895
# FLAG_DOCUMENT_21 Sample represents the Population

# %%
#alpha = 0.1
diff_cols = [i[0] for i in l if i[1]==0] #not good fit samples 
diff_cols
#Sample and Population proportion for below are different for alpha = 0.1
# Out:
# ['FLAG_MOBIL', 'FLAG_DOCUMENT_10']

# %% [markdown]
# ### Target vs Unbalanced Categorical Samples from above
# Chi-Square Test for Independence
# This test is used to test whether the categorical variables are independent or not.
#
# 𝐻0
# : The variables are independent
#
# 𝐻1
# : The variables are not independent (i.e. variables are dependent)

# %%
#lets see whether these columns are dependent or independent of TARGET
def target_vs_cat_test(col,alpha=0.05):
    table = pd.crosstab(df_pop['TARGET'],df_pop[col])
    test_stat, p, dof, expected_value = stats.chi2_contingency(observed = table, correction = False)
    if p < alpha/2:
        print(f'{col} is Dependent/Significant p_val:{p}')
        return (col,0)
    else:
        print(f'{col} is Independent/NotSignificant p_val:{p}')
        return (col,1)

# %%
l = []
for col in diff_cols:
    l.append(target_vs_cat_test(col))
# Out:
# FLAG_MOBIL is Independent/NotSignificant p_val:0.7669689262880788
# FLAG_DOCUMENT_10 is Independent/NotSignificant p_val:0.4330079310907313

# %%
sig_cols = [i[0] for i in l if i[1]==0] #Significant Columns 
sig_cols
# Out:
# []

# %% [markdown]
# #### After taking different random samples and running the statistical tests on these samples, we got a sample which statisfied most of the Statistical tests. Saving it for continuing further as good sample.

# %%
#Save the Random sample

# %%
df_samp.to_csv('sample_40k_good_fit.csv')
