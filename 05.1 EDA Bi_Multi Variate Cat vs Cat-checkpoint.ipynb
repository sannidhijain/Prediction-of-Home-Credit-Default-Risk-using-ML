# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None
pd.options.display.max_rows=150
pd.options.display.max_colwidth = None

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,8)

import seaborn as sns

# %%
df = pd.read_csv('sample_train_good_40k.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)
col_desc = pd.read_csv('HomeCredit_columns_description.csv')
description = col_desc[col_desc['Table']=='application_{train|test}.csv'][['Row','Description','Special']]
description
# Out:
#                               Row  \
# 0                      SK_ID_CURR
# 1                          TARGET
# 2              NAME_CONTRACT_TYPE
# 3                     CODE_GENDER
# 4                    FLAG_OWN_CAR
# 5                 FLAG_OWN_REALTY
# 6                    CNT_CHILDREN
# 7                AMT_INCOME_TOTAL
# 8                      AMT_CREDIT
# 9                     AMT_ANNUITY
# 10                AMT_GOODS_PRICE
# 11                NAME_TYPE_SUITE
# 12               NAME_INCOME_TYPE
# 13            NAME_EDUCATION_TYPE
# 14             NAME_FAMILY_STATUS
# 15              NAME_HOUSING_TYPE
# 16     REGION_POPULATION_RELATIVE
# 17                     DAYS_BIRTH
# 18                  DAYS_EMPLOYED
# 19              DAYS_REGISTRATION
# 20                DAYS_ID_PUBLISH
# 21                    OWN_CAR_AGE
# 22                     FLAG_MOBIL
# 23                 FLAG_EMP_PHONE
# 24                FLAG_WORK_PHONE
# 25               FLAG_CONT_MOBILE
# ...

# %%
def get_description_of_column(col,df=description):
    return description[description['Row']==col]

# %%
dtypes = df.apply(lambda col: col.dtype)
null_count = df.isnull().sum()
nuniques = df.apply(lambda col:col.nunique())

df_info = pd.DataFrame({'dtypes':dtypes,'null_count':null_count,'nuniques':nuniques})
df_info
# Out:
#                                dtypes  null_count  nuniques
# TARGET                          int64           0         2
# NAME_CONTRACT_TYPE             object           0         2
# CODE_GENDER                    object           0         2
# FLAG_OWN_CAR                   object           0         2
# FLAG_OWN_REALTY                object           0         2
# CNT_CHILDREN                    int64           0        10
# AMT_INCOME_TOTAL              float64           0       647
# AMT_CREDIT                    float64           0      3102
# AMT_ANNUITY                   float64           1      8156
# AMT_GOODS_PRICE               float64          35       473
# NAME_TYPE_SUITE                object         172         7
# NAME_INCOME_TYPE               object           0         8
# NAME_EDUCATION_TYPE            object           0         5
# NAME_FAMILY_STATUS             object           0         5
# NAME_HOUSING_TYPE              object           0         6
# ...

# %%
num_cat_col = df_info[(df_info['dtypes']!='object')&(df_info['nuniques']<4)].index
num_col = df_info[(df_info['dtypes']!='object')&(df_info['nuniques']>=4)].index
cat_col = df_info[df_info['dtypes']=='object'].index

print(len(num_col)+len(cat_col)+len(num_cat_col))

cat_col = list(num_cat_col) + list(cat_col)
# Out:
# 121

# %%
print('Number of Categorical columns:',len(cat_col))
print()
print(cat_col)
# Out:
# Number of Categorical columns: 51
#
# ...

# %% [markdown]
# #### TARGET
# We have already did Bivariate Analysis for TARGET with other columns in Univariate Analysis

# %%
### Categorical vs Categorical

# %%
def cat_vs_cat_plot(df,col1,col2):
    t = pd.crosstab(df[col1],df[col2])
    print(f'Crosstab {col1} vs {col2}:')
    display(t)
    t2 = pd.crosstab(df[col1],df[col2],normalize=0)
    print(f'Crosstab Normalized {col1} vs {col2}:')
    display(t2)
    t.plot(kind='bar')
    plt.title(f'{col1} vs {col2}')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# #### Communication Related

# %%
comm_cols = ['FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL']

# %%
for i in range(len(comm_cols)):
    col1 = comm_cols[i]
    for j in range(i+1,len(comm_cols)):
        col2 = comm_cols[j]
        print(f'{col1} Description:',get_description_of_column(col1)['Description'].values[0])
        print(f'{col2} Description:',get_description_of_column(col2)['Description'].values[0])
        cat_vs_cat_plot(df,col1,col2)
        print('-'*100)
# Out:
# FLAG_MOBIL Description: Did client provide mobile phone (1=YES, 0=NO)
# FLAG_EMP_PHONE Description: Did client provide work phone (1=YES, 0=NO)
# Crosstab FLAG_MOBIL vs FLAG_EMP_PHONE:
# FLAG_EMP_PHONE     0      1
# FLAG_MOBIL
# 1               7235  32765
# Crosstab Normalized FLAG_MOBIL vs FLAG_EMP_PHONE:
# FLAG_EMP_PHONE         0         1
# FLAG_MOBIL
# 1               0.180875  0.819125
# ----------------------------------------------------------------------------------------------------
# FLAG_MOBIL Description: Did client provide mobile phone (1=YES, 0=NO)
# FLAG_WORK_PHONE Description: Did client provide home phone (1=YES, 0=NO)
# Crosstab FLAG_MOBIL vs FLAG_WORK_PHONE:
# FLAG_WORK_PHONE      0     1
# FLAG_MOBIL
# 1                32002  7998
# Crosstab Normalized FLAG_MOBIL vs FLAG_WORK_PHONE:
# FLAG_WORK_PHONE        0        1
# FLAG_MOBIL
# 1                0.80005  0.19995
# ...

# %% [markdown]
# #### Region Related columns

# %%
region_cols = ['REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY']

# %%
for i in range(len(region_cols)):
    col1 = region_cols[i]
    for j in range(i+1,len(region_cols)):
        col2 = region_cols[j]
        print(f'{col1} Description:',get_description_of_column(col1)['Description'].values[0])
        print(f'{col2} Description:',get_description_of_column(col2)['Description'].values[0])
        cat_vs_cat_plot(df,col1,col2)
        print('-'*100)
# Out:
# REGION_RATING_CLIENT Description: Our rating of the region where client lives (1,2,3)
# REGION_RATING_CLIENT_W_CITY Description: Our rating of the region where client lives with taking city into account (1,2,3)
# Crosstab REGION_RATING_CLIENT vs REGION_RATING_CLIENT_W_CITY:
# REGION_RATING_CLIENT_W_CITY     1      2     3
# REGION_RATING_CLIENT
# 1                            4181      0     0
# 2                             161  29264     0
# 3                              91    508  5795
# Crosstab Normalized REGION_RATING_CLIENT vs REGION_RATING_CLIENT_W_CITY:
# REGION_RATING_CLIENT_W_CITY         1         2         3
# REGION_RATING_CLIENT
# 1                            1.000000  0.000000  0.000000
# 2                            0.005472  0.994528  0.000000
# 3                            0.014232  0.079449  0.906318
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Document Related

# %%
document_cols = ['FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 
                 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11',
                 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16',
                 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21']
doc_df = df[document_cols].sum(axis=0).sort_values(ascending=False)
display(doc_df)
plt.pie(doc_df,labels=doc_df.index,autopct='%.2f')
plt.show()
# Out:
# FLAG_DOCUMENT_3     28524
# FLAG_DOCUMENT_6      3487
# FLAG_DOCUMENT_8      3215
# FLAG_DOCUMENT_5       579
# FLAG_DOCUMENT_16      401
# FLAG_DOCUMENT_18      317
# FLAG_DOCUMENT_9       156
# FLAG_DOCUMENT_11      150
# FLAG_DOCUMENT_13      131
# FLAG_DOCUMENT_14      116
# FLAG_DOCUMENT_15       49
# FLAG_DOCUMENT_19       22
# FLAG_DOCUMENT_20       20
# FLAG_DOCUMENT_17        9
# FLAG_DOCUMENT_21        8
# FLAG_DOCUMENT_7         6
# FLAG_DOCUMENT_2         2
# FLAG_DOCUMENT_4         1
# FLAG_DOCUMENT_10        0
# FLAG_DOCUMENT_12        0
# dtype: int64

# %%
g = df.groupby('TARGET')[document_cols].sum().
g.get_group(0).sum(axis=0)
# Out:
# FLAG_DOCUMENT_2         1
# FLAG_DOCUMENT_3     26000
# FLAG_DOCUMENT_4         1
# FLAG_DOCUMENT_5       533
# FLAG_DOCUMENT_6      3287
# FLAG_DOCUMENT_7         6
# FLAG_DOCUMENT_8      2964
# FLAG_DOCUMENT_9       149
# FLAG_DOCUMENT_10        0
# FLAG_DOCUMENT_11      136
# FLAG_DOCUMENT_12        0
# FLAG_DOCUMENT_13      128
# FLAG_DOCUMENT_14      113
# FLAG_DOCUMENT_15       46
# FLAG_DOCUMENT_16      378
# FLAG_DOCUMENT_17        9
# FLAG_DOCUMENT_18      303
# FLAG_DOCUMENT_19       20
# FLAG_DOCUMENT_20       18
# FLAG_DOCUMENT_21        6
# dtype: int64

# %%
g.get_group(1).sum(axis=0)
# Out:
# FLAG_DOCUMENT_2        1
# FLAG_DOCUMENT_3     2524
# FLAG_DOCUMENT_4        0
# FLAG_DOCUMENT_5       46
# FLAG_DOCUMENT_6      200
# FLAG_DOCUMENT_7        0
# FLAG_DOCUMENT_8      251
# FLAG_DOCUMENT_9        7
# FLAG_DOCUMENT_10       0
# FLAG_DOCUMENT_11      14
# FLAG_DOCUMENT_12       0
# FLAG_DOCUMENT_13       3
# FLAG_DOCUMENT_14       3
# FLAG_DOCUMENT_15       3
# FLAG_DOCUMENT_16      23
# FLAG_DOCUMENT_17       0
# FLAG_DOCUMENT_18      14
# FLAG_DOCUMENT_19       2
# FLAG_DOCUMENT_20       2
# FLAG_DOCUMENT_21       2
# dtype: int64

# %%
g.sum().T
# Out:
# TARGET                0     1
# FLAG_DOCUMENT_2       1     1
# FLAG_DOCUMENT_3   26000  2524
# FLAG_DOCUMENT_4       1     0
# FLAG_DOCUMENT_5     533    46
# FLAG_DOCUMENT_6    3287   200
# FLAG_DOCUMENT_7       6     0
# FLAG_DOCUMENT_8    2964   251
# FLAG_DOCUMENT_9     149     7
# FLAG_DOCUMENT_10      0     0
# FLAG_DOCUMENT_11    136    14
# FLAG_DOCUMENT_12      0     0
# FLAG_DOCUMENT_13    128     3
# FLAG_DOCUMENT_14    113     3
# FLAG_DOCUMENT_15     46     3
# FLAG_DOCUMENT_16    378    23
# FLAG_DOCUMENT_17      9     0
# FLAG_DOCUMENT_18    303    14
# FLAG_DOCUMENT_19     20     2
# FLAG_DOCUMENT_20     18     2
# FLAG_DOCUMENT_21      6     2

# %%
df['FLAG_DOCUMENT_12'].value_counts()
# Out:
# 0    40000
# Name: FLAG_DOCUMENT_12, dtype: int64

# %% [markdown]
# 87% have submitted only one document

# %%
table = pd.crosstab(doc_df,df['TARGET'],normalize=0)*100
display(table)
table.plot(kind='bar')
plt.show()
# Out:
# TARGET          0          1
# row_0
# 0       94.560125   5.439875
# 1       91.492631   8.507369
# 2       95.146613   4.853387
# 3       86.956522  13.043478

# %% [markdown]
# #### Remaining Categorical Columns

# %%
remaining_cat_cols = set(cat_col) - {'TARGET'} - set(comm_cols) - set(region_cols) - set(document_cols)
remaining_cat_cols
# Out:
# {'CODE_GENDER',
#  'EMERGENCYSTATE_MODE',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'FONDKAPREMONT_MODE',
#  'HOUSETYPE_MODE',
#  'NAME_CONTRACT_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'NAME_INCOME_TYPE',
#  'NAME_TYPE_SUITE',
#  'OCCUPATION_TYPE',
#  'ORGANIZATION_TYPE',
#  'WALLSMATERIAL_MODE',
#  'WEEKDAY_APPR_PROCESS_START'}
