# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None
pd.options.display.max_rows=150
pd.options.display.max_colwidth = None

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,8)

import seaborn as sns

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split 

from sklearn.linear_model import LogisticRegression

from sklearn import metrics

import statsmodels.api as sm

from scipy import stats

# %%
df = pd.read_csv('sample_train_good_100k_with_user_ids.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)
col_desc = pd.read_csv('HomeCredit_columns_description.csv')
description = col_desc[col_desc['Table']=='application_{train|test}.csv'][['Row','Description','Special']]
description
# Out:
#                               Row  \
# 0                      SK_ID_CURR
# 1                          TARGET
# 2              NAME_CONTRACT_TYPE
# 3                     CODE_GENDER
# 4                    FLAG_OWN_CAR
# 5                 FLAG_OWN_REALTY
# 6                    CNT_CHILDREN
# 7                AMT_INCOME_TOTAL
# 8                      AMT_CREDIT
# 9                     AMT_ANNUITY
# 10                AMT_GOODS_PRICE
# 11                NAME_TYPE_SUITE
# 12               NAME_INCOME_TYPE
# 13            NAME_EDUCATION_TYPE
# 14             NAME_FAMILY_STATUS
# 15              NAME_HOUSING_TYPE
# 16     REGION_POPULATION_RELATIVE
# 17                     DAYS_BIRTH
# 18                  DAYS_EMPLOYED
# 19              DAYS_REGISTRATION
# 20                DAYS_ID_PUBLISH
# 21                    OWN_CAR_AGE
# 22                     FLAG_MOBIL
# 23                 FLAG_EMP_PHONE
# 24                FLAG_WORK_PHONE
# 25               FLAG_CONT_MOBILE
# ...

# %%
def get_description_of_column(col,df=description):
    return description[description['Row']==col]

# %%
user_ids = df['SK_ID_CURR']

# %%
#From Statistical test, significant columns are
num_cols = ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 
            'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'HOUR_APPR_PROCESS_START',
            'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'YEARS_BUILD_AVG', 'ELEVATORS_AVG',
            'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'APARTMENTS_MODE', 
            'YEARS_BUILD_MODE', 'ELEVATORS_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LIVINGAREA_MODE', 
            'APARTMENTS_MEDI', 'YEARS_BUILD_MEDI', 'ELEVATORS_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI',
            'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 
            'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 
            'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_YEAR']

cat_cols = ['FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 
            'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_3', 
            'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_18', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
            'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 
            'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE']
cat_cols.append('TARGET')

# %%
df = df[num_cols+cat_cols]

# %% [markdown]
# #### 365243 in DAYS_EMPLOYED is Nan

# %%
df['DAYS_EMPLOYED'].value_counts()
# Out:
#  365243    18173
# -200          57
# -230          55
# -745          53
# -116          51
#            ...
# -8923          1
# -6878          1
# -13081         1
# -8987          1
# -8132          1
# Name: DAYS_EMPLOYED, Length: 9821, dtype: int64

# %%
df['DAYS_EMPLOYED'].replace(365243,np.nan,inplace=True)

# %%
df['DAYS_EMPLOYED'].value_counts()
# Out:
# -200.0      57
# -230.0      55
# -745.0      53
# -193.0      51
# -116.0      51
#             ..
# -14019.0     1
# -9915.0      1
# -8468.0      1
# -14018.0     1
#  0.0         1
# Name: DAYS_EMPLOYED, Length: 9820, dtype: int64

# %%
df_num = df[num_cols]
df_cat = df[cat_cols].select_dtypes(object)
df_num_cat = df[cat_cols].select_dtypes(np.number)

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   CNT_CHILDREN                100000 non-null  int64
#  1   AMT_INCOME_TOTAL            100000 non-null  float64
#  2   AMT_CREDIT                  100000 non-null  float64
#  3   AMT_GOODS_PRICE             99905 non-null   float64
#  4   REGION_POPULATION_RELATIVE  100000 non-null  float64
#  5   DAYS_BIRTH                  100000 non-null  int64
#  6   DAYS_EMPLOYED               81827 non-null   float64
#  7   DAYS_REGISTRATION           100000 non-null  float64
#  8   DAYS_ID_PUBLISH             100000 non-null  int64
#  9   OWN_CAR_AGE                 33943 non-null   float64
#  10  HOUR_APPR_PROCESS_START     100000 non-null  int64
#  11  EXT_SOURCE_1                43623 non-null   float64
# ...

# %%
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   NAME_CONTRACT_TYPE   100000 non-null  object
#  1   CODE_GENDER          100000 non-null  object
#  2   FLAG_OWN_CAR         100000 non-null  object
#  3   NAME_INCOME_TYPE     100000 non-null  object
#  4   NAME_EDUCATION_TYPE  100000 non-null  object
#  5   NAME_FAMILY_STATUS   100000 non-null  object
#  6   NAME_HOUSING_TYPE    100000 non-null  object
#  7   OCCUPATION_TYPE      68639 non-null   object
#  8   ORGANIZATION_TYPE    100000 non-null  object
#  9   FONDKAPREMONT_MODE   31556 non-null   object
#  10  HOUSETYPE_MODE       49746 non-null   object
#  11  WALLSMATERIAL_MODE   49115 non-null   object
# dtypes: object(12)
# memory usage: 9.2+ MB

# %%
df_num_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   FLAG_EMP_PHONE               100000 non-null  int64
#  1   FLAG_WORK_PHONE              100000 non-null  int64
#  2   FLAG_PHONE                   100000 non-null  int64
#  3   REGION_RATING_CLIENT         100000 non-null  int64
#  4   REGION_RATING_CLIENT_W_CITY  100000 non-null  int64
#  5   REG_CITY_NOT_LIVE_CITY       100000 non-null  int64
#  6   REG_CITY_NOT_WORK_CITY       100000 non-null  int64
#  7   LIVE_CITY_NOT_WORK_CITY      100000 non-null  int64
#  8   FLAG_DOCUMENT_3              100000 non-null  int64
#  9   FLAG_DOCUMENT_6              100000 non-null  int64
#  10  FLAG_DOCUMENT_13             100000 non-null  int64
#  11  FLAG_DOCUMENT_18             100000 non-null  int64
# ...

# %% [markdown]
# #### Standardizing Numerical

# %%
(df_num.std()==0).sum()
# Out:
# 0

# %%
#no column has zero deviation so can go with Standard Scalar
df_num = (df_num-df_num.mean())/df_num.std()

# %%
df_num.shape
# Out:
# (100000, 42)

# %%
df_num['DAYS_EMPLOYED'].isnull().sum()
# Out:
# 18173

# %%
null_count = df_num.isnull().sum()
null_prop = (null_count[null_count!=0]/df_num.shape[0])*100
null_prop[null_prop>10].sort_values()
#null_prop
# Out:
# AMT_REQ_CREDIT_BUREAU_YEAR    13.447
# AMT_REQ_CREDIT_BUREAU_MON     13.447
# DAYS_EMPLOYED                 18.173
# EXT_SOURCE_3                  19.772
# TOTALAREA_MODE                48.321
# FLOORSMAX_MEDI                49.830
# FLOORSMAX_AVG                 49.830
# FLOORSMAX_MODE                49.830
# LIVINGAREA_AVG                50.199
# LIVINGAREA_MEDI               50.199
# LIVINGAREA_MODE               50.199
# APARTMENTS_MEDI               50.846
# APARTMENTS_AVG                50.846
# APARTMENTS_MODE               50.846
# ELEVATORS_MEDI                53.352
# ELEVATORS_AVG                 53.352
# ELEVATORS_MODE                53.352
# EXT_SOURCE_1                  56.377
# OWN_CAR_AGE                   66.057
# YEARS_BUILD_MEDI              66.598
# YEARS_BUILD_AVG               66.598
# YEARS_BUILD_MODE              66.598
# FLOORSMIN_MEDI                67.897
# FLOORSMIN_MODE                67.897
# FLOORSMIN_AVG                 67.897
# ...

# %%
df_num2 = df_num.copy(deep=True)

# %%
null_cols = null_prop[null_prop>10].index
for i in null_cols:
    df_num2[i+'_NULL'] = df_num[i].isnull().astype(int)

# %%
df_num2.isnull().sum()
# Out:
# CNT_CHILDREN                           0
# AMT_INCOME_TOTAL                       0
# AMT_CREDIT                             0
# AMT_GOODS_PRICE                       95
# REGION_POPULATION_RELATIVE             0
# DAYS_BIRTH                             0
# DAYS_EMPLOYED                      18173
# DAYS_REGISTRATION                      0
# DAYS_ID_PUBLISH                        0
# OWN_CAR_AGE                        66057
# HOUR_APPR_PROCESS_START                0
# EXT_SOURCE_1                       56377
# EXT_SOURCE_2                         233
# EXT_SOURCE_3                       19772
# APARTMENTS_AVG                     50846
# YEARS_BUILD_AVG                    66598
# ELEVATORS_AVG                      53352
# FLOORSMAX_AVG                      49830
# FLOORSMIN_AVG                      67897
# LIVINGAPARTMENTS_AVG               68390
# LIVINGAREA_AVG                     50199
# APARTMENTS_MODE                    50846
# YEARS_BUILD_MODE                   66598
# ...

# %%
df_num2[null_cols] = df_num2[null_cols].replace(np.nan,0)

# %%
df_num2.shape
# Out:
# (100000, 69)

# %% [markdown]
# #### Dummy Encoding Categorical Columns

# %%
df_cat.shape
# Out:
# (100000, 12)

# %%
n = df_cat.isnull().sum()
n[n!=0]
# Out:
# OCCUPATION_TYPE       31361
# FONDKAPREMONT_MODE    68444
# HOUSETYPE_MODE        50254
# WALLSMATERIAL_MODE    50885
# dtype: int64

# %%
null_cat_cols = n[n!=0].index

# %%
df_cat[null_cat_cols] = df_cat[null_cat_cols].replace(np.nan,'Unspecified')

# %%
n = df_cat.isnull().sum()
n[n!=0]
# Out:
# Series([], dtype: int64)

# %%
df_cat = pd.get_dummies(df_cat,drop_first=True)
df_cat.shape
# Out:
# (100000, 113)

# %% [markdown]
# #### Merging Num, Cat, Num_cat

# %%
df_new = pd.concat([df_num2,df_cat,df_num_cat],axis=1)
df_new.shape
# Out:
# (100000, 195)

# %% [markdown]
# #### Null Treatment

# %%
df_new['SK_ID_CURR'] = user_ids

# %%
null_count = df_new.isnull().sum()
null_prop = (null_count[null_count!=0]/df_new.shape[0])*100
null_prop.sort_values()
# Out:
# AMT_GOODS_PRICE             0.095
# EXT_SOURCE_2                0.233
# OBS_30_CNT_SOCIAL_CIRCLE    0.337
# DEF_30_CNT_SOCIAL_CIRCLE    0.337
# OBS_60_CNT_SOCIAL_CIRCLE    0.337
# DEF_60_CNT_SOCIAL_CIRCLE    0.337
# dtype: float64

# %%
df_new_without_nulls = df_new.dropna()

# %%
df_new_without_nulls.shape
# Out:
# (99338, 196)

# %%
df_new_without_nulls.head()
# Out:
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  \
# 0     -0.576642         -0.042651   -0.703297        -0.701817
# 1     -0.576642         -0.229157   -0.192867        -0.239036
# 2     -0.576642         -0.147561   -0.369957        -0.239036
# 3     -0.576642         -0.205844   -1.095622        -1.079349
# 4     -0.576642         -0.089278    0.300837         0.491670
#
#    REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  \
# 0                   -1.146791   -0.967668       0.000000           0.149491
# 1                    0.760564   -0.473696       0.760395          -0.177024
# 2                    0.760564    0.281897       0.049211           0.163379
# 3                   -1.073908   -1.792097       0.000000          -2.412741
# 4                    0.402885    1.272355       0.270411           0.208445
#
#    DAYS_ID_PUBLISH  OWN_CAR_AGE  HOUR_APPR_PROCESS_START  EXT_SOURCE_1  \
# ...

# %%
df_new_without_nulls.to_csv('sample_100k_null_treated.csv',index=False)

# %% [markdown]
# ### BaseModel

# %%
df_new_without_nulls = pd.read_csv('sample_30k_null_treated.csv')

# %%
X = df_new_without_nulls.drop(['TARGET','SK_ID_CURR'],axis=1)
y = df_new_without_nulls['TARGET']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_test.shape
# Out:
# (19868, 194)

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# C:\Users\sgp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_scores = lr.predict_proba(X_test)[:,1]
metrics.roc_auc_score(y_test,y_scores)
# Out:
# 0.7467903502628929

# %%
fpr,tpr,t = metrics.roc_curve(y_test,y_scores)
ind = np.argmax(tpr-fpr)
optimal_t = t[ind]
y_pred = (y_scores>optimal_t)*1
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.67      0.79     18242
#            1       0.16      0.69      0.26      1626
#
#     accuracy                           0.67     19868
#    macro avg       0.56      0.68      0.52     19868
# weighted avg       0.90      0.67      0.75     19868

# %%
plt.plot(fpr,tpr)

# %%
pip install scikitplot
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement scikitplot (from versions: none)
# ERROR: No matching distribution found for scikitplot
#
# [notice] A new release of pip is available: 23.0 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scikitplot as skplt

skplt.metrics.plot_roc_curve(y_test, y_scores)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cac4630a19ad> in <module>
# ----> 1 import scikitplot as skplt
#       2
#       3 skplt.metrics.plot_roc_curve(y_test, y_scores)
#       4 plt.show()
#
# ModuleNotFoundError: No module named 'scikitplot'

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_scores = lr.predict_proba(X_test)[:,1]
metrics.roc_auc_score(y_test,y_scores)
# Out:
# 0.7468664084733162

# %%
fpr,tpr,t = metrics.roc_curve(y_test,y_scores)
ind = np.argmax(tpr-fpr)
optimal_t = t[ind]
y_pred = (y_scores>optimal_t)*1
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.67      0.79     18242
#            1       0.16      0.69      0.26      1626
#
#     accuracy                           0.67     19868
#    macro avg       0.56      0.68      0.52     19868
# weighted avg       0.90      0.67      0.75     19868

# %%
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
f_imp = pd.DataFrame({'imp':rf.feature_importances_},index=X.columns).sort_values(by='imp',ascending=False).head(50)
f_imp
# Out:
#                                                imp
# EXT_SOURCE_2                              0.056502
# EXT_SOURCE_3                              0.054101
# DAYS_BIRTH                                0.039945
# DAYS_REGISTRATION                         0.039895
# DAYS_ID_PUBLISH                           0.039744
# DAYS_EMPLOYED                             0.036392
# DAYS_LAST_PHONE_CHANGE                    0.035833
# AMT_CREDIT                                0.034934
# AMT_INCOME_TOTAL                          0.030958
# REGION_POPULATION_RELATIVE                0.030600
# AMT_GOODS_PRICE                           0.030354
# EXT_SOURCE_1                              0.027860
# HOUR_APPR_PROCESS_START                   0.027686
# AMT_REQ_CREDIT_BUREAU_YEAR                0.019775
# OWN_CAR_AGE                               0.016478
# OBS_60_CNT_SOCIAL_CIRCLE                  0.015686
# OBS_30_CNT_SOCIAL_CIRCLE                  0.015517
# ...

# %%
temp = f_imp.head(30)
#plt.figure(figsize=(15,15))
sns.barplot(y=temp.index,x=temp['imp'],orientation='horizontal')
#plt.xticks(rotation=90)
plt.show()

# %%
metrics.accuracy_score(y_test,rf.predict(X_test))
# Out:
# 0.920536462699078

# %%
cm = metrics.confusion_matrix(y_test,rf.predict(X_test))
metrics.ConfusionMatrixDisplay(cm).plot()

# %%
y_pred_prob = rf.predict_proba(X_test)

# %%
y_pred_prob[y_test==1][:,1][:100]
# Out:
# array([0.17, 0.17, 0.09, 0.16, 0.17, 0.21, 0.14, 0.21, 0.16, 0.07, 0.16,
#        0.02, 0.26, 0.02, 0.02, 0.19, 0.3 , 0.06, 0.06, 0.37, 0.36, 0.2 ,
#        0.13, 0.08, 0.02, 0.18, 0.26, 0.2 , 0.07, 0.03, 0.16, 0.08, 0.03,
#        0.3 , 0.1 , 0.16, 0.02, 0.06, 0.04, 0.14, 0.32, 0.1 , 0.06, 0.13,
#        0.09, 0.09, 0.15, 0.14, 0.23, 0.22, 0.08, 0.12, 0.11, 0.12, 0.16,
#        0.18, 0.03, 0.21, 0.04, 0.02, 0.01, 0.03, 0.35, 0.3 , 0.16, 0.21,
#        0.2 , 0.05, 0.15, 0.24, 0.17, 0.15, 0.16, 0.13, 0.06, 0.17, 0.06,
#        0.31, 0.06, 0.23, 0.06, 0.29, 0.07, 0.03, 0.14, 0.1 , 0.08, 0.18,
#        0.23, 0.06, 0.05, 0.01, 0.03, 0.14, 0.03, 0.18, 0.08, 0.01, 0.17,
#        0.1 ])

# %%
y_pred_prob[y_test==1][:,1].mean()
# Out:
# 0.13137130801687763

# %%
y_pred_prob[y_test==1][:,1].min()
# Out:
# 0.0

# %%
y_pred_prob[y_test==1][:,1].max()
# Out:
# 0.51

# %%
y_pred_prob[y_test==0][:,1][:100]
# Out:
# array([0.104, 0.086, 0.056, 0.03 , 0.054, 0.066, 0.178, 0.038, 0.096,
#        0.054, 0.034, 0.054, 0.186, 0.054, 0.094, 0.166, 0.05 , 0.03 ,
#        0.05 , 0.066, 0.15 , 0.082, 0.106, 0.082, 0.098, 0.05 , 0.032,
#        0.048, 0.1  , 0.088, 0.142, 0.092, 0.074, 0.172, 0.054, 0.076,
#        0.094, 0.076, 0.03 , 0.082, 0.11 , 0.072, 0.07 , 0.046, 0.12 ,
#        0.05 , 0.044, 0.16 , 0.094, 0.2  , 0.04 , 0.056, 0.094, 0.084,
#        0.032, 0.05 , 0.09 , 0.052, 0.054, 0.05 , 0.03 , 0.064, 0.052,
#        0.154, 0.102, 0.04 , 0.166, 0.084, 0.054, 0.044, 0.128, 0.244,
#        0.228, 0.018, 0.028, 0.212, 0.08 , 0.104, 0.114, 0.108, 0.036,
#        0.086, 0.038, 0.082, 0.156, 0.216, 0.018, 0.212, 0.042, 0.058,
#        0.158, 0.022, 0.202, 0.094, 0.11 , 0.114, 0.082, 0.036, 0.136,
#        0.218])

# %%
y_pred_prob[y_test==0][:,1].mean()
# Out:
# 0.08438903657530479

# %%
y_pred_prob[y_test==0][:,1].min()
# Out:
# 0.0

# %%
y_pred_prob[y_test==0][:,1].max()
# Out:
# 0.49

# %%
y_pred_prob = rf.predict_proba(X_test)
#y_pred = (y_pred_prob>0.14).astype(int).argmax(axis=1)
y_pred = y_pred_prob.argmax(axis=1)
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(cm).plot()
metrics.roc_auc_score(y_test,y_pred_prob.max(axis=1))
# Out:
# 0.29033976411694173

# %%
y_pred_prob = rf.predict_proba(X_test)
#y_pred = (y_pred_prob>0.14).astype(int).argmax(axis=1)
y_pred = (y_pred_prob[:,1]>0.08).astype(int)
cm = metrics.confusion_matrix(y_test,y_pred)
metrics.ConfusionMatrixDisplay(cm).plot()
metrics.roc_auc_score(y_test,y_pred_prob[:,1])
# Out:
# 0.6830701869649377

# %%
tps,fps,thresholds = metrics.roc_curve(y_test,y_pred_prob[:,1])
plt.plot(fps,tps)

# %%
d = pd.DataFrame({'fps':fps,'tps':tps,'threshold':thresholds})
d['diff'] = d['fps']-d['tps']
d.sort_values(by='diff',inplace=True)
d.head()
# Out:
#      fps       tps  threshold      diff
# 2    0.0  0.000183      0.352 -0.000183
# 1    0.0  0.000092      0.360 -0.000092
# 0    0.0  0.000000      1.360  0.000000
# 159  1.0  1.000000      0.006  0.000000
# 158  1.0  0.999817      0.008  0.000183

# %%
logits = sm.Logit(y_train,sm.add_constant(X_train)).fit()
print(logits.summary)
# Out:
# ...
#          Current function value: 0.246624
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-40-70b92b65a3a8> in <module>
# ----> 1 logits = sm.Logit(y_train,sm.add_constant(X_train)).fit()
#       2 print(logits.summary)
#
# ~\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1972     def fit(self, start_params=None, method='newton', maxiter=35,
#    1973             full_output=1, disp=1, callback=None, **kwargs):
# -> 1974         bnryfit = super().fit(start_params=start_params,
#    1975                               method=method,
#    1976                               maxiter=maxiter,
#
# ...

# %% [markdown]
# The problem arises due to the perfect correlation between the two series in your data. From the traceback, you can see, that internally a wald test is used to compute the maximum likelihood estimates for the parameters of the lag-time series. To do this an estimate of the parameters covariance matrix (which is then near-zero) and its inverse is needed (as you can also see in the line invcov = np.linalg.inv(cov_p) in the traceback). This near-zero matrix is now singular for some maximum lag number (>=5) and thus the test crashes. If you add just a little noise to your data, the error disappears:
#
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from statsmodels.tsa.stattools import grangercausalitytests
#
# n = 1000
# ls = np.linspace(0, 2*np.pi, n)
# df1Clean = pd.DataFrame(np.sin(ls))
# df2Clean = pd.DataFrame(2*np.sin(ls+1))
# dfClean = pd.concat([df1Clean, df2Clean], axis=1)
# dfDirty = dfClean+0.00001*np.random.rand(n, 2)
#
# grangercausalitytests(dfClean, maxlag=20, verbose=False)    # Raises LinAlgError
# grangercausalitytests(dfDirty, maxlag=20, verbose=False)    # Runs fine

# %%
#Removing correlated columns
corr_cols = ['FLOORSMIN_AVG', 'APARTMENTS_MEDI', 'FLOORSMIN_MEDI', 'LIVINGAPARTMENTS_AVG', 'FLOORSMAX_AVG', 'LIVINGAREA_AVG', 
 'ELEVATORS_AVG', 'YEARS_BUILD_AVG', 'LIVINGAREA_MEDI', 'ELEVATORS_MEDI', 'YEARS_BUILD_MEDI', 'APARTMENTS_AVG', 
 'FLOORSMAX_MEDI','OBS_60_CNT_SOCIAL_CIRCLE']
X2 = X.drop(corr_cols,axis=1)
X2['DAYS_EMPLOYED'].replace(365243,0,inplace=True)
X_train,X_test,y_train,y_test = train_test_split(X2,y,test_size=0.2,random_state=10)

# %%
logits = sm.Logit(y_train,sm.add_constant(X_train)).fit()
print(logits.summary)
# Out:
# ...
#          Current function value: inf
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-167-70b92b65a3a8> in <module>
# ----> 1 logits = sm.Logit(y_train,sm.add_constant(X_train)).fit()
#       2 print(logits.summary)
#
# ~\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1972     def fit(self, start_params=None, method='newton', maxiter=35,
#    1973             full_output=1, disp=1, callback=None, **kwargs):
# -> 1974         bnryfit = super().fit(start_params=start_params,
#    1975                               method=method,
#    1976                               maxiter=maxiter,
#
# ...

# %%
corr = X2.corr()
sns.heatmap(corr[corr==1],cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Fine tune RF

# %%
d = {}

for min_samples_split in [2,5,10,15,20,25]:
    for max_depth in [2,5,7,10]:
        rf = RandomForestClassifier(max_depth=max_depth,min_samples_split=min_samples_split)
        rf.fit(X_train,y_train)
        #display(pd.DataFrame({'imp':rf.feature_importances_},index=X.columns).sort_values(by='imp',ascending=False).head(50))
        y_pred_prob = rf.predict_proba(X_test)
        score = metrics.roc_auc_score(y_test,y_pred_prob[:,1])
        d[f'max_depth:{max_depth}, min_samples_split:{min_samples_split} min_samples_leaf:{min_samples_leaf}'] = score
d_sorted = sorted(d,key=lambda x:d[x],reverse=True)
f'Parameters: {d_sorted[0]} Score:{d[d_sorted[0]]}'
# Out:
# 'Parameters: max_depth:5, min_samples_split:10 min_samples_leaf:1 Score:0.7226332003193565'

# %%
d = {}

for min_samples_split in [2,5,10,15,20,25]:
    for max_depth in [2,5,7,10]:
        rf = RandomForestClassifier(max_depth=max_depth,min_samples_split=min_samples_split)
        rf.fit(X_train,y_train)
        #display(pd.DataFrame({'imp':rf.feature_importances_},index=X.columns).sort_values(by='imp',ascending=False).head(50))
        y_pred_prob = rf.predict_proba(X_test)
        score = metrics.roc_auc_score(y_test,y_pred_prob[:,1])
        d[f'max_depth:{max_depth}, min_samples_split:{min_samples_split}'] = score
d_sorted = sorted(d,key=lambda x:d[x],reverse=True)
f'Parameters: {d_sorted[0]} Score:{d[d_sorted[0]]}'
# Out:
# 'Parameters: max_depth:10, min_samples_split:10 Score:0.7199817576440773'
