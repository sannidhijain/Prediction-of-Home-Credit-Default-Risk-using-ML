# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None
pd.options.display.max_rows=150
pd.options.display.max_colwidth = None

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,8)

import seaborn as sns

# %%
df = pd.read_csv('sample_train_good_40k.csv')
df.drop('Unnamed: 0',axis=1,inplace=True)
col_desc = pd.read_csv('HomeCredit_columns_description.csv')
description = col_desc[col_desc['Table']=='application_{train|test}.csv'][['Row','Description','Special']]
def get_description_of_column(col,df=description):
    return description[description['Row']==col]

# %%
#From Statistical test, significant columns are
num_cols = ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 
            'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'HOUR_APPR_PROCESS_START',
            'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'YEARS_BUILD_AVG', 'ELEVATORS_AVG',
            'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'APARTMENTS_MODE', 
            'YEARS_BUILD_MODE', 'ELEVATORS_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LIVINGAREA_MODE', 
            'APARTMENTS_MEDI', 'YEARS_BUILD_MEDI', 'ELEVATORS_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI',
            'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 
            'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 
            'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_YEAR']

cat_cols = ['FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 
            'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_3', 
            'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_18', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
            'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 
            'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE']
cat_cols.append('TARGET')

# %%
df_sig = df[num_cols+cat_cols].copy(deep=True)

# %%
corr = df_sig.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
[            'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG','APARTMENTS_MEDI', 'YEARS_BUILD_AVG', 'ELEVATORS_AVG',
            'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'APARTMENTS_MODE', 
            'YEARS_BUILD_MODE', 'ELEVATORS_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LIVINGAREA_MODE', 
            'YEARS_BUILD_MEDI', 'ELEVATORS_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI',
            'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 
            'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 
            'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_YEAR']

# %%
l = []

# %%
for i in num_cols:
    if str.startswith(i,'LIVINGAPARTMENTS_'):
        l.append(i)
l
# Out:
# ['APARTMENTS_AVG',
#  'APARTMENTS_MODE',
#  'APARTMENTS_MEDI',
#  'YEARS_BUILD_AVG',
#  'YEARS_BUILD_MODE',
#  'YEARS_BUILD_MEDI',
#  'ELEVATORS_AVG',
#  'ELEVATORS_MODE',
#  'ELEVATORS_MEDI',
#  'FLOORSMAX_AVG',
#  'FLOORSMAX_MODE',
#  'FLOORSMAX_MEDI',
#  'FLOORSMIN_AVG',
#  'FLOORSMIN_MODE',
#  'FLOORSMIN_MEDI',
#  'LIVINGAREA_AVG',
#  'LIVINGAREA_MODE',
#  'LIVINGAREA_MEDI',
#  'LIVINGAPARTMENTS_AVG',
#  'LIVINGAPARTMENTS_MEDI']

# %%
print(l)
# Out:
# ['APARTMENTS_AVG', 'APARTMENTS_MODE', 'APARTMENTS_MEDI', 'YEARS_BUILD_AVG', 'YEARS_BUILD_MODE', 'YEARS_BUILD_MEDI', 'ELEVATORS_AVG', 'ELEVATORS_MODE', 'ELEVATORS_MEDI', 'FLOORSMAX_AVG', 'FLOORSMAX_MODE', 'FLOORSMAX_MEDI', 'FLOORSMIN_AVG', 'FLOORSMIN_MODE', 'FLOORSMIN_MEDI', 'LIVINGAREA_AVG', 'LIVINGAREA_MODE', 'LIVINGAREA_MEDI', 'LIVINGAPARTMENTS_AVG', 'LIVINGAPARTMENTS_MEDI']

# %%
sns.heatmap(corr[l])
# Out:
# <AxesSubplot:>

# %%
# we can similarity between same column types, so we can remove similar columns

# %%
l1 = ['APARTMENTS_AVG', 'APARTMENTS_MODE', 'APARTMENTS_MEDI', 'YEARS_BUILD_AVG', 'YEARS_BUILD_MODE', 'YEARS_BUILD_MEDI', 'ELEVATORS_AVG', 'ELEVATORS_MODE', 'ELEVATORS_MEDI', 'FLOORSMAX_AVG', 'FLOORSMAX_MODE', 'FLOORSMAX_MEDI', 'FLOORSMIN_AVG', 'FLOORSMIN_MODE', 'FLOORSMIN_MEDI', 'LIVINGAREA_AVG', 'LIVINGAREA_MODE', 'LIVINGAREA_MEDI', 'LIVINGAPARTMENTS_AVG', 'LIVINGAPARTMENTS_MEDI']
l2 = ['APARTMENTS_MODE','YEARS_BUILD_MODE','ELEVATORS_MODE','FLOORSMAX_MODE','FLOORSMIN_MODE','LIVINGAREA_MODE','LIVINGAPARTMENTS_MEDI']
l2
# Out:
# ['APARTMENTS_MODE',
#  'YEARS_BUILD_MODE',
#  'ELEVATORS_MODE',
#  'FLOORSMAX_MODE',
#  'FLOORSMIN_MODE',
#  'LIVINGAREA_MODE',
#  'LIVINGAPARTMENTS_MEDI']

# %%
#columns need to be dropped
l3 = set(l1)-set(l2)
l3
# Out:
# {'APARTMENTS_AVG',
#  'APARTMENTS_MEDI',
#  'ELEVATORS_AVG',
#  'ELEVATORS_MEDI',
#  'FLOORSMAX_AVG',
#  'FLOORSMAX_MEDI',
#  'FLOORSMIN_AVG',
#  'FLOORSMIN_MEDI',
#  'LIVINGAPARTMENTS_AVG',
#  'LIVINGAREA_AVG',
#  'LIVINGAREA_MEDI',
#  'YEARS_BUILD_AVG',
#  'YEARS_BUILD_MEDI'}

# %%
df_sig.drop(l3,axis=1,inplace=True)

# %%
corr = df_sig.corr()
plt.figure(figsize=(30,30))
sns.heatmap(corr,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
print(num_cols)
# Out:
# ['CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'HOUR_APPR_PROCESS_START', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'YEARS_BUILD_AVG', 'ELEVATORS_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'APARTMENTS_MODE', 'YEARS_BUILD_MODE', 'ELEVATORS_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LIVINGAREA_MODE', 'APARTMENTS_MEDI', 'YEARS_BUILD_MEDI', 'ELEVATORS_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_YEAR']

# %%
print(cat_cols)
# Out:
# ['FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_18', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'WALLSMATERIAL_MODE', 'TARGET']

# %%
sns.heatmap(corr[['OBS_30_CNT_SOCIAL_CIRCLE','OBS_60_CNT_SOCIAL_CIRCLE','DEF_30_CNT_SOCIAL_CIRCLE','DEF_60_CNT_SOCIAL_CIRCLE']],cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
df_sig.drop('OBS_60_CNT_SOCIAL_CIRCLE',axis=1,inplace=True)

# %%
corr = df_sig.corr()
plt.figure(figsize=(30,30))
sns.heatmap(corr,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(corr[['DAYS_EMPLOYED','FLAG_EMP_PHONE']],cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
df['DAYS_EMPLOYED'].value_counts(normalize=True)
# Out:
#  365243    0.180800
# -214       0.000600
# -339       0.000575
# -224       0.000575
# -380       0.000550
#              ...
# -6989      0.000025
# -4942      0.000025
# -4974      0.000025
# -7085      0.000025
# -8364      0.000025
# Name: DAYS_EMPLOYED, Length: 7560, dtype: float64

# %%
df[df['DAYS_EMPLOYED']==365243].TARGET.value_counts()
# Out:
# 0    6849
# 1     383
# Name: TARGET, dtype: int64

# %%
df_sig['DAYS_EMPLOYED'].replace(365243,np.nan,inplace=True)

# %%
corr = df_sig.corr()
sns.heatmap(corr[['DAYS_EMPLOYED','FLAG_EMP_PHONE']],cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = df_sig.corr()
sns.heatmap(corr,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Conclusion

# %%
print(l3)
# Out:
# {'FLOORSMIN_AVG', 'APARTMENTS_MEDI', 'FLOORSMIN_MEDI', 'LIVINGAPARTMENTS_AVG', 'FLOORSMAX_AVG', 'LIVINGAREA_AVG', 'ELEVATORS_AVG', 'YEARS_BUILD_AVG', 'LIVINGAREA_MEDI', 'ELEVATORS_MEDI', 'YEARS_BUILD_MEDI', 'APARTMENTS_AVG', 'FLOORSMAX_MEDI'}

# %%
#Removed numerical columns are
['FLOORSMIN_AVG', 'APARTMENTS_MEDI', 'FLOORSMIN_MEDI', 'LIVINGAPARTMENTS_AVG', 'FLOORSMAX_AVG', 'LIVINGAREA_AVG', 
 'ELEVATORS_AVG', 'YEARS_BUILD_AVG', 'LIVINGAREA_MEDI', 'ELEVATORS_MEDI', 'YEARS_BUILD_MEDI', 'APARTMENTS_AVG', 
 'FLOORSMAX_MEDI','OBS_60_CNT_SOCIAL_CIRCLE']
# Out:
# ['FLOORSMIN_AVG',
#  'APARTMENTS_MEDI',
#  'FLOORSMIN_MEDI',
#  'LIVINGAPARTMENTS_AVG',
#  'FLOORSMAX_AVG',
#  'LIVINGAREA_AVG',
#  'ELEVATORS_AVG',
#  'YEARS_BUILD_AVG',
#  'LIVINGAREA_MEDI',
#  'ELEVATORS_MEDI',
#  'YEARS_BUILD_MEDI',
#  'APARTMENTS_AVG',
#  'FLOORSMAX_MEDI',
#  'OBS_60_CNT_SOCIAL_CIRCLE']
